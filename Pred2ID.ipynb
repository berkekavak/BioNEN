# %%
import os,sys, requests

# %%
# Species -> NCBI Taxonomy
# Protein -> Uniprod ID

# Human ->9606

# HIV ->

# API Frontend?


# Tezde ekstra normalization veya named entity recognition’ı geliştirebilirsin.

# %%
ex = 'Homo sapiens'

# %%
species_name='cows'
url = f"https://www.ncbi.nlm.nih.gov/taxonomy/?term={species_name}"
requests.get(url)
# Out:
# <Response [200]>

# %%
def get_taxonomy_id(species_name):
    url = f"https://www.ncbi.nlm.nih.gov/taxonomy/?term={species_name}"
    response = requests.get(url)
    html_text = response.text
    start_index = html_text.find("data-taxid=") + len("data-taxid=")
    end_index = html_text.find(">", start_index)
    taxonomy_id = html_text[start_index:end_index].strip('"')
    return taxonomy_id

# Example usage:
taxonomy_id = get_taxonomy_id("Homo sapiens")
print(taxonomy_id) # prints "9606"
# Out:
# ion="1.0" encoding="utf-8"?

# %%
biodct = {}
# !rm -rf 'data/.DS_Store'
for file in os.listdir('data'):
    with open('data/'+file) as f:
        print(file)
        lines = [line.rstrip('\n') for line in f]
        for line in lines:
            if len(line.split('\t'))>1:
                biodct[line.split()[3]] = line.split()[-1]
# Out:
# BC5CDR_TrainDev.PubTator
# BioID_Train_revision.PubTator
# BioRED_TrainDev.PubTator
# GNormPlus_Train.PubTator
# Linnaeus_Train.PubTator
# NCBIdisease_TrainDev.PubTator
# NLMchem_TrainDev.PubTator
# NLMgene_Train.PubTator
# SPECIES_Train.PubTator
# tmVar3_Train.PubTator

# %%
biodct
# Out:
# {'Naloxone': 'D009270',
#  'clonidine': 'D003000',
#  'hypertensive': 'D006973',
#  'nalozone': '-1',
#  'hypotensive': 'D007022',
#  'alpha-methyldopa': 'D008750',
#  'naloxone': 'D009270',
#  '[3H]-naloxone': '-1',
#  '[3H]-dihydroergocryptine': '-1',
#  'Lidocaine': 'D008012',
#  'cardiac': 'D006332',
#  'lidocaine': 'MESH:D008012',
#  'depression': 'D003866',
#  'bradyarrhythmias': 'D001919',
#  'Suxamethonium': 'D013390',
#  'fasciculations': 'D005207',
#  'Sch': 'D013390',
#  'tetanic': 'D013746',
#  'Fasciculations': 'D005207',
#  'fasciculation': 'D005207',
#  'twitch': 'D013746',
#  'tetanus': 'D013746',
#  'Galanthamine': 'D005702',
#  'scopolamine': 'D012601',
#  'Hyoscine': 'D012601',
#  'hyoscine': 'D012601',
#  'overdosage': 'D062787',
#  'physostigmine': 'D010830',
#  'lithium': 'MESH:C040949',
#  'chronic': 'D006505',
#  'nephropathy': 'D007674',
#  'renal': 'D007674',
#  'Li': 'D008094',
#  'Lithium': 'D008094',
#  'proteinuria': 'D011507',
#  'hypertension': 'D006973',
#  'glomerulosclerosis': 'D005921',
#  'creatinine': 'MESH:D003404',
#  "Crohn's": 'D003424',
#  'fusidic': 'D005672',
#  'cyclosporin': 'D016572',
#  'Fusidic': 'D005672',
#  'nausea': 'D009325',
#  'inflammatory': 'D015212',
#  'myocardial': 'D009203',
#  'cocaine': 'D003042',
#  'schizophrenic': 'D012559',
#  'ischemia': 'D007511',
#  'bundle': 'D002037',
#  'Sulpiride': 'D013469',
#  'tardive': 'D004409',
#  'antidepressant': 'D000928',
#  'sulpiride': 'D013469',
#  'parkinsonism': 'D010302',
#  'dystonia': 'D004421',
#  'Ocular': 'D014786|D006311',
#  'desferrioxamine': 'D003676',
#  'audiovisual': 'D014786|D006311',
#  'visual': 'D014786',
#  'Visual': 'D014786',
#  'dyschromatopsy': '-1',
#  'a': '6022',
#  'pigmentary': 'D012174',
#  'Auditory': 'D004827',
#  'neurosensorial': 'D006319',
#  'Desferrioxamine': 'D003676',
#  'hearing': 'D034381',
#  'toxicity': 'D064420',
#  'aluminium': 'MESH:D000535',
#  'Myasthenia': 'D009157',
#  'magnesium': 'MESH:D008274',
#  'neuromuscular': 'D009468',
#  'quadriplegic': 'D011782',
#  'preeclampsia': 'D011225',
#  'postsynaptic': 'D009468',
#  'acetylcholine': 'MESH:D000109',
#  'paralysis': 'D010243',
#  'myasthenia': 'D009157',
#  'disorder': 'D004194',
#  'Chloroacetaldehyde': 'C004656',
#  'cyclophosphamide': 'D003520',
#  'ifosfamide': 'D007069',
#  'chloroacetaldehyde': 'C004656',
#  'CAA': 'C004656',
#  'hemorrhagic': 'D006470',
#  'bladder': 'D001749',
#  'mesna': 'D015080',
#  'pain': 'D010146',
#  'migraine': 'D008881',
#  'nitroglycerin': 'D005996',
#  'Clotiazepam': 'C084599',
#  'hepatitis': 'D006526',
#  'extensive': 'D047508',
#  'clotiazepam': 'C084599',
#  'thienodiazepine': 'C013295',
#  'benzodiazepines': 'D001569',
#  'hepatotoxicity': 'D056486',
#  'ketoconazole': 'D007654',
#  "Cushing's": 'D003480',
#  'cortisol': 'C535280',
#  'deoxycorticosterone': 'D064791',
#  '11-deoxycortisol': 'D003350',
#  'aldosterone': 'D000450',
#  'angiotensin': '1636',
#  'Captopril': 'D002216',
#  'pulmonary': 'D000081029',
#  'intravascular': 'D004211',
#  'tranexamic': 'D014148',
#  'AMCA': 'D014148',
#  'trauma': 'D014947',
#  'sepsis': 'D018805',
#  'Renal': 'D002292',
#  'urea': 'MESH:D014508',
#  'Angiotension': 'D000804',
#  'prostacyclin': 'MESH:D011464',
#  'bradykinin': '3827',
#  'kidney': 'C566906',
#  'labetalol': 'D007741',
#  'nitroprusside': 'D009599',
#  'hypotension': 'D007022',
#  'reductions': 'D007022',
#  'increase': 'D006973',
#  'Labetalol': 'D007741',
#  'PO2': 'C093415',
#  'carbamazepine': 'D002220',
#  'folate': 'MESH:D005492',
#  'Folate': 'D005492',
#  'Carbamazepine': 'D002220',
#  'CBZ': 'D002220',
#  'propylene': 'D019946',
#  'seizures': 'D012640',
#  'weight': 'D015430',
#  'Seizures': 'D012640',
#  'hexafluorodiethyl': 'D005481',
#  'HFDE': 'D005481',
#  'sodium': '110876,20265,20269,20272,20273,24766,29571,29701,29710,497770,64155,78956,81574',
#  'norepinephrine': 'MESH:D009638',
#  'epinephrine': 'MESH:D004837',
#  'tachycardia': 'D013610',
#  'hydralazine': 'D006830',
#  'Death': 'D003643',
#  'gestational': 'D031901',
#  'choriocarcinoma': 'D002822',
#  'Etoposide': 'D005047',
#  'Methotrexate': 'MESH:D008727',
#  'Cyclophosphamide': 'D003520',
#  'Actomycin-D': 'D003609',
#  'Cisplatin': 'D002945',
#  'tumor': 'D009369',
#  'necrosis': 'D009336',
#  'embolism': 'D004617',
#  'pelvic': 'D010386',
#  'Sexual': 'D012735',
#  'arthritis': 'D001168',
#  'sexual': 'D050035',
#  'rheumatoid': 'D001172',
#  'osteoarthritis': 'D010003',
#  'spondyloarthropathy': 'D025242',
#  'depressed': 'D003866',
#  'Impotence': 'D007172',
#  'methotrexate': 'MESH:D008727',
#  'Depressed': 'D003866',
#  'impotence': 'D007172',
#  'paracetamol': 'D000082',
#  'urothelial': 'D001745',
#  'cancer': 'D009369',
#  'phenacetin': 'MESH:D010615',
#  'ureteric': 'D014516',
#  'cancers': 'D009369',
#  'Dapsone': 'D003622',
#  'hemolytic': 'D000743',
#  'leprosy': 'D007918',
#  'dapsone': 'D003622',
#  'hemolysis': 'D006461',
#  'glutathione': '2944',
#  'GSH': 'MESH:D005978',
#  'pentose': 'D010428',
#  'infection': 'D007239',
#  'metoprolol': 'D008790',
#  'propafenone': 'D011405',
#  'diltiazem': 'D004110',
#  'sparteine': 'D013034',
#  'coronary': 'D003324',
#  'shock': 'D012769',
#  'AV': 'D054537',
#  'impairment': 'D007153',
#  'debrisoquine': 'D003647',
#  'adverse': 'D064420',
#  'Triazolam': 'D014229',
#  'mania': 'D001714',
#  'triazolam': 'D014229',
#  'organic': '89776',
#  'delirium': 'D003693',
#  'Manic': 'D001714',
#  'triazolo': 'D014229',
#  'muscular': 'D009136',
#  'morphine': 'D009020',
#  'rigidity': 'D009127',
#  'akinetic': 'D018476',
#  'hyperkinetic': 'D006948',
#  'haloperidol': 'MESH:D006220',
#  'Haloperidol': 'MESH:D006220',
#  'Compression': 'D009408|D020425',
#  'pentazocine': 'D010423',
#  'fibrous': 'D005355|D009135',
#  'Fibrous': 'D005355|D009135',
#  'compression': 'D009408',
#  'myopathy': 'D009135',
#  'acute': 'D015473',
#  'amphotericin': 'D000666',
#  'cirrhosis': 'D005355',
#  'sporotrichosis': 'D013174',
#  'pleural': 'D010995',
#  'neuropathy': 'D009422',
#  'amiodarone': 'D000638',
#  'sinuatrial': 'D002318',
#  'supraventricular': 'D013617',
#  'pneumonitis': 'D011014',
#  'proximal': 'D009468',
#  'prednisolone': 'D011239',
#  'steroid': '10499',
#  'Indomethacin': 'MESH:D007213',
#  'hyperkalemia': 'D006947',
#  'ascites': 'D001201',
#  'cor': 'D011660',
#  'indomethacin': 'MESH:D007213',
#  'oliguria': 'D009846',
#  'prostaglandins': 'MESH:D011453',
#  'flunitrazepam': 'D005445',
#  'Flunitrazepam': 'D005445',
#  'Dizziness': 'D004244',
#  'timolol': 'D013999',
#  'bradycardia': 'D001919',
#  'cardiomegaly': 'D006332',
#  'infarction': 'D007238',
#  'Vitamin': '2638',
#  'vitamin': '7421',
#  'hypercalcemia': 'D006934',
#  'hyperphosphatemia': 'D054559',
#  'Calcium': '24247',
#  'milk': '1056',
#  'Diseases': 'D010523',
#  'peripheral': 'D010523',
#  'Sensori-motor': 'D010523',
#  'Guillain-Barr': 'D020275',
#  'motor': 'D019957',
#  'Peripheral': 'D010523',
#  'nutritional': 'D044342',
#  'thiamine': 'MESH:D013831',
#  'riboflavin': 'MESH:D012256',
#  'sensori-motor': 'D010523',
#  'Diabetes': 'D003920',
#  'autonomic': 'D009422',
#  'Isoniazid': 'D007538',
#  'Migraine': 'D008881',
#  'cranial': 'D003389',
#  'malignancies': 'D009369',
#  'connective': '64032',
#  'neuropathies': 'D009422',
#  'dothiepin': 'D004308',
#  'depressive': 'D000275',
#  'amitriptyline': 'D000639',
#  'Dothiepin': 'D004308',
#  'blurred': 'D014786',
#  'dry': 'D014987',
#  'diazepam': 'D003975',
#  'propranolol': 'D011433',
#  'panic': 'D016584',
#  'agoraphobia': 'D000379',
#  'impaired': 'D018149',
#  'Delayed': 'D008569',
#  'behavioral': 'D001523',
#  'aspirin': 'MESH:D001241',
#  'N-[4-(5-nitro-2-furyl)-2-thiazolyl]-formamide': 'D005200',
#  'FANFT': 'D005200',
#  'forestomach': 'D013274',
#  'carcinogenesis': 'D063646',
#  'diabetic': 'D003920',
#  'estrogen': '2099',
#  'adenohypophyseal': 'D010911',
#  'Pituitary': 'D010911',
#  'diethylstilbestrol': 'D004054',
#  'DES': 'D004054',
#  'acriflavine': 'D000167',
#  'Triamterene': 'D014223',
#  'nephrolithiasis': 'D053040',
#  'dyazide': 'C020743',
#  'triamterene': 'D014223',
#  'hydrochlorothiazide-triamterene': 'C020743',
#  'uric': 'MESH:D014527',
#  'adriamycin': 'D004317',
#  'cardiotoxicity': 'D066126',
#  'cardiotoxic': 'D066126',
#  'Adriamycin': 'D004317',
#  'phosphorylcreatine': 'D010725',
#  'phophorylcreatine': 'D010725',
#  'creatine': 'MESH:D003401',
#  'adenosine': '135',
#  'ATP': 'MESH:D000255',
#  'neurotoxic': 'D020258',
#  'streptomycin': 'MESH:D013307',
#  'Streptomycin': 'D013307',
#  'Abnormal': 'D003117',
#  'deafness': 'D003638',
#  'dyskinesias': 'D004409',
#  'glomerulonephritis': 'D005921',
#  'rifampin': 'D012293',
#  'isoniazid': 'D007538',
#  'puromycin': 'MESH:D011691',
#  'oxygen': 'MESH:D017382',
#  'PAN': 'D011692',
#  'thiobarbituric': 'MESH:C029684',
#  'Proteinuria': 'D011507',
#  'proteinuric': 'D011507',
#  'Clomipramine': 'D002997',
#  'sleep': 'D012891',
#  'clomipramine': 'D002997',
#  'Angioedema': 'D000799',
#  'chest': 'D002637',
#  'diabetes': 'D003920',
#  'angioedema': 'D000799',
#  'lisinopril': 'D017706',
#  'steroids': 'MESH:D013256',
#  'diphenhydramine': 'D004155',
#  'coniine': 'C007112',
#  'Coniine': 'C007112',
#  'arthrogryposis': 'D001176',
#  'nicotine': 'D009538',
#  'deformations': 'D009140',
#  'excessive': 'D000435',
#  'prostaglandin': 'MESH:D011453',
#  'trimethaphan': 'D014294',
#  'PGE1': 'D000527',
#  'TMP': 'D014294',
#  'isoflurane': 'MESH:D007530',
#  'axonal': 'D020833',
#  'injury': 'D007674',
#  'lactate': '24533',
#  'Infarcts': 'D002544',
#  'pilocarpine': 'D010862',
#  'status': 'D008881',
#  'traumatic': 'D014947',
#  'Parkinson': 'D010300',
#  'fluoxetine': 'D005473',
#  'Depression': 'D003866',
#  "Parkinson's": 'D010300',
#  'idiopathic': 'C535761',
#  'dopamine': '1815',
#  'Acetaminophen': 'D000082',
#  'acetaminophen': 'MESH:D000082',
#  'cardiovascular': 'D002318',
#  'anaphylaxis': 'D000707',
#  'critically': 'D016638',
#  'allergic': 'D004342',
#  'autoimmune': 'D001327',
#  'erythroblastocytopenia': '-1',
#  'ceftriaxone': 'D002443',
#  'beta': 'D017086',
#  'bilirubin': 'MESH:D001663',
#  'extrapyramidal': 'D001480',
#  'EPS': 'MESH:D011135',
#  'orthostatic': 'D007024',
#  'seizure': 'D012640',
#  'clozapine': 'MESH:D003024',
#  'agranulocytosis': 'D000380',
#  'tetrandrine': 'C009438',
#  'fangchinoline': 'C060802',
#  'thrombosis': 'D013927',
#  'platelet': 'D001791',
#  'Tetrandrine': 'C009438',
#  'TET': 'C009438',
#  'FAN': 'C060802',
#  'bisbenzylisoquinoline': 'D044182',
#  'EP': 'D004837',
#  'blood': 'MESH:D001786',
#  'acetylsalicylic': 'D001241',
#  'ASA': 'D001241',
#  'Gemcitabine': 'C056507',
#  'vinorelbine': 'D000077235',
#  'nonsmall': 'D002289',
#  'cisplatin': 'MESH:D002945',
#  'NSCLC': 'D002289',
#  'VNB': 'D000077235',
#  'gemcitabine': 'C056507',
#  'GEM': 'C056507',
#  'Toxicity': 'D064420',
#  'neutropenia': 'D009503',
#  'thrombocytopenia': 'D013921',
#  'neurotoxicity': 'D020258',
#  'myelosuppression': 'D001855',
#  'Warfarin': 'D014859',
#  'artery': 'D002532',
#  'calcification': 'D002114',
#  'phosphate': 'MESH:D010710',
#  'calcium': '778',
#  'gamma-carboxylated': 'D015055',
#  'gamma-carboxyglutamate': 'D015055',
#  'Antidepressant': 'D000928',
#  'bipolar': 'D001714',
#  'antidepressants': 'D000928',
#  'manic': 'D001714',
#  'hypomanic': 'D001714',
#  'DSM-IV': 'D001714',
#  'serotonin': '6532',
#  'SSRIs': 'D017367',
#  'hypomania': 'D001714',
#  'Caffeine': 'D002110',
#  'mitral': 'D008945',
#  'ventricular': 'D020257',
#  'caffeine': 'D002110',
#  'retention': 'D016055',
#  'fentanyl': 'D005283',
#  'Fentanyl': 'D005283',
#  'respiratory': 'D028361',
#  'urinary': 'D014570',
#  'hydronephrosis': 'D006869',
#  'cardiomyopathy': 'D009202',
#  'AIDS': 'D000163',
#  'CM': 'OMIM:610102',
#  'LA': 'D005693',
#  'mitochondrial': 'C580039',
#  'zidovudine': 'D015215',
#  'lamivudine': 'D019259',
#  'indinavir': 'D019469',
#  'Oral': 'D003276',
#  'oral': 'D002971|D002972',
#  'progestagen': 'D011372',
#  'desogestrel': 'MESH:D017135',
#  'gestodene': 'C033273',
#  'levonorgestrel': 'D016912',
#  'oral-contraceptive': 'D003276',
#  'locomotor': 'D006948',
#  'GR': '2908',
#  'CP': 'MESH:D002733',
#  'hyperlocomotion': 'D009069',
#  'Ticlopidine': 'D013988',
#  'cholestatic': 'D041781',
#  'ticlopidine': 'D013988',
#  'Cholestatic': 'D041781',
#  'jaundice': 'D007565',
#  'Hepatitis': '12475',
#  'cholestasis': 'D002779',
#  'clopidogrel': 'D000077144',
#  'nephrotic': 'D009404',
#  'Sodium': '6323',
#  'NO': 'MESH:D009569',
#  'calcitonin': '-',
#  'CGRP': '24241',
#  '5-hydroxytriptamine': 'D012701',
#  '5-HT': 'D012701',
#  'headache': 'D020773',
#  'migraineurs': 'D008881',
#  'Coronary': 'D003324',
#  'paclitaxel': 'MESH:D017239',
#  'aneurysm': 'D000783',
#  'vessel': '-1',
#  'urotensin-II': '24111',
#  'Urotensin-II': '24111',
#  'U-II': '24111',
#  'apomorphine': 'D001058',
#  'penile': 'D004414',
#  'corticosterone': 'MESH:D003345',
#  'psychiatric': 'D001523',
#  'dysphonia': 'D055154',
#  'acitretin': 'D017255',
#  'tissue': '7078',
#  'secondary': 'D006962',
#  'Secondary': 'D006930',
#  'neurogenic': 'D006930',
#  'neuropathic': 'D009437',
#  'hyperalgesia': 'D006930',
#  'gabapentin': 'D000077206',
#  'capsaicin': 'MESH:D002211',
#  'MDMA': 'D018817',
#  'memory': 'D008569',
#  '3,4-methylenedioxymethamphetamine': 'D018817',
#  'ecstasy': 'D018817',
#  'citrate': 'MESH:D019343',
#  'hyperlipidemia': 'D006949',
#  'bumetanide': 'MESH:D002034',
#  'pravastatin': 'D017035',
#  'paroxetine': 'D017374',
#  'tetany': 'D013746',
#  'muscle': 'D009135',
#  'hypocalcemia': 'D006996',
#  'loop': 'D049994',
#  'sirolimus': 'D020123',
#  'Sirolimus': 'D020123',
#  'SRL': 'D020123',
#  'CAN': 'D007674',
#  'neoplasia': 'D001749',
#  "Kaposi's": '37296',
#  'skin': 'D012871',
#  'intestinal': 'C537394',
#  'membranoproliferative': 'D015433',
#  'interstitial': 'D009395',
#  'cystitis': 'D003556',
#  'atropine': 'D001285',
#  'alpha,beta-methylene': 'C002630',
#  'alpha,beta-meATP': 'C002630',
#  '4-diphenylacetoxy-N-methylpiperidine': 'C042375',
#  '4-DAMP': 'C042375',
#  'methoctramine': 'C054938',
#  'pirenzepine': 'D010890',
#  'carbachol': 'MESH:D002217',
#  'potassium': 'MESH:C013216',
#  'isoprenaline': 'D007545',
#  'BZDs': 'D001569',
#  'oxazepam': 'D010076',
#  'temazepam': 'D013693',
#  'zopiclone': 'C515050',
#  'dementia': 'D003704',
#  'dizziness': 'D004244',
#  'inability': 'D050033',
#  'tiredness': 'D005221',
#  'vocal': 'D014826',
#  'disulfiram': 'D004221',
#  'overdose': 'D062787',
#  'quadriparesis': 'D011782',
#  'sensory': 'D015417',
#  'paresthesia': 'D010292',
#  'ALCOHOL': 'D000431',
#  'ataxia': 'D001259',
#  'giddiness': 'D004244',
#  'hoarseness': 'D006685',
#  'polyneuropathy': 'D011115',
#  'palsy': 'D010243',
#  'heparin': 'MESH:D006493',
#  'HIT': 'D013921',
#  'thrombotic': 'D013927',
#  'retinal': 'D012162',
#  'clomiphene': 'D002996',
#  'CC': 'c|SUB|C||T;Gene:7157;Disease:D012878;VariantGroup:0',
#  'infertility': 'D007247',
#  'thromboembolic': 'D013923',
#  'Nicotine': 'D009538',
#  'nystagmus': 'D009759',
#  'NIN': 'D009759',
#  'verapamil': 'D014700',
#  'gastric': 'D013274',
#  'ulcers': 'D014456',
#  'atherosclerotic': 'D050197',
#  'histamine': '11255,3269,3274,59340',
#  'ulcer': 'D013276',
#  'atherosclerosis': 'D050197',
#  'cholesterol': 'MESH:D002784',
#  'luminal': 'DomainMotif',
#  'Atherosclerosis': 'D050197',
#  'death': 'D003643',
#  'heart': 'D006333',
#  '3-methyladenine': 'MESH:C025946',
#  '3MA': 'C025946',
#  'K': '6934',
#  'Confusion': 'D003221',
#  'valproic': 'MESH:D014635',
#  'confusion': 'D003221',
#  'Learning': 'D007859,D008569',
#  'impairments': 'D007859,D019958',
#  'cannabis': 'D002188',
#  'Deficits': 'D007859,D008569',
#  'hyperactivity': 'D006948',
#  'Ecstasy': 'D018817',
#  'argatroban': 'C031942',
#  'HITT': 'D013921|D013927',
#  'intraoperative': 'D016063|D019106',
#  'hepatic': 'D008107',
#  'coagulopathy': 'D001778',
#  'Antituberculosis': 'D000995',
#  'ALF': 'D017114',
#  'tuberculosis': 'D014376',
#  'icterus': 'D007565',
#  'encephalopathy': 'D001927',
#  'cerebral': 'D000326',
#  'Gastrointestinal': 'D005768',
#  'Central': 'D003711',
#  'ALL': 'D054198',
#  'neurological': 'D009422',
#  'leukemic': 'D007938',
#  'neurocognitive': 'D002493',
#  'leukoencephalopathy': 'D056784',
#  'stroke': 'D020521',
#  'temporal': 'D004833',
#  'inappropriate': 'D007177',
#  'capecitabine': 'D000069287',
#  'Fluoropyrimidines': '-',
#  '5-fluorouracil': 'D005472',
#  '5-FU': 'D005472',
#  'tumors': 'D009369',
#  'colorectal,': 'D010051|D016889|D015179',
#  'Capecitabine': 'D000069287',
#  'diarrhea': 'D003967',
#  'vomiting': 'D014839',
#  'stomatitis': 'D013280',
#  'hand-foot': 'D060831',
#  'neurotensin': 'D009496',
#  'parkinsonian': 'D010300',
#  'SR48692': 'C079087',
#  'Hypertensive': 'D006973',
#  'depressions': 'D003866',
#  'methyl': 'MESH:C475457',
#  'H2O': 'MESH:D014867',
#  'decrease': 'D007022|D001919',
#  'decreased': 'OMIM:613779',
#  'Nitroprusside': 'D009599',
#  'decreases': '-1',
#  'L-dopa': 'D007980',
#  'L-Dopa': 'D007980',
#  'MK-486': 'D002230',
#  'DL-Threo-dihydroxyphenylserine': 'D015103',
#  'FLA-63': 'D005406',
#  'Pimozide': 'D010868',
#  '5-HTP': 'D006916',
#  'Cocaine': 'D003042',
#  'spasm': 'D013035',
#  'thrombus': 'D013927',
#  'Rabbit': '9986',
#  'rabbit': '9986',
#  'imipramine': 'D007099',
#  'movement': 'D009069',
#  'ipratropium': 'D009241',
#  'theophylline': 'D013806',
#  'RPN': 'D007681',
#  'polyuria': 'D011141',
#  'hyperthermia': 'D005334',
#  'toxicities': 'D064420',
#  'leukopenia': 'D007970',
#  'Prazosin': 'D011224',
#  'stress': 'D015775',
#  'prazosin': 'D011224',
#  'incontinence': 'D014549',
#  'Myocardial': 'D017202',
#  'isosorbide': 'D007547',
#  'Fluoxetine': 'D005473',
#  'akathisia': 'D017109',
#  'obsessive': 'D009771',
#  'major': '3123,720',
#  'anxiety': 'D001008',
#  'Akathisia': 'D017109',
#  'Chronic': 'D006461',
#  'diclofenac': 'MESH:D004008',
#  'Diclofenac': 'MESH:D004008',
#  'Voltarol': 'D004008',
#  'phenylacetic': 'C025136',
#  'abnormalities': 'D002658',
#  'Stroke': 'D020521',
#  'Intracranial': 'D002532',
#  'arteriovenous': 'D001165',
#  'Cerebral': 'D002543',
#  'intracerebral': 'D002543',
#  'subarachnoid': 'D013345',
#  'intracranial': 'D019586',
#  'Glyburide': 'D005905',
#  'sulfonylureas': 'D013453',
#  'glyburide': 'D005905',
#  'sulfonylurea': '6833',
#  'type': 'D003924',
#  'viral': 'D001102',
#  'drug-induced': 'D056486',
#  'hemorrhage': 'D006470',
#  'HEM': 'D006470',
#  'SNP': 'MESH:D009599',
#  'hypovolemia': 'D020896',
#  'vasospasm': 'D014652',
#  'gangrene': 'D005734',
#  'xenon': 'D014978',
#  'nitrous': 'D009609',
#  'Hg': 'D008628',
#  'Allergic': 'D004342',
#  'angioneurotic': 'D000799',
#  'carcinoma': 'D002277',
#  'prednisone': 'D011241',
#  'Amiodarone': 'D000638',
#  'sinoatrial': 'D012848',
#  'primary': 'D008831',
#  'Wolff-Parkinson-White': 'D014927',
#  'sinus': 'D012804',
#  'sulphasalazine': 'D012460',
#  'congenital': 'D003409',
#  'ulcerative': 'D003093',
#  'coarctation': 'D001017',
#  'Potter-type': 'D007690',
#  'rudimentary': '-1',
#  "Potter's": '-1',
#  'hypoplastic': 'D005489',
#  'absent': '-1',
#  'talipes': 'D003025',
#  'Veno-occlusive': 'D006504',
#  'dacarbazine': 'D003606',
#  'DTIC': 'D003606',
#  'melanoma': 'D008545',
#  'veno-occlusive': 'D006504',
#  'venous': 'D054556',
#  'metoclopramide': 'D008787',
#  'gastrointestinal': 'D005770,D008175',
#  'abnormal': 'D025861',
#  'intra-Hisian': 'D006327',
#  'atrial': '24602',
#  'intraventricular': 'D000074042,D002543',
#  'Busulfan': 'D002066',
#  'busulfan': 'D002066',
#  'saralasin': 'D012504',
#  'halothane': 'MESH:D006221',
#  'Toxic': 'D056486',
#  'carbimazole': 'D002231',
#  'benzylthiouracil': 'C019269',
#  'hyperthyroidism': 'D006980',
#  'toxic': 'D010523',
#  'N': 'MESH:D009584',
#  'Benzylthiouracil': 'C019269',
#  'Basd': 'C019269',
#  'folinic': 'D002955',
#  'ZDV': 'D015215',
#  'bone': 'D000080983',
#  'human': '9606',
#  'myelotoxicity': 'D001855',
#  'cisplatinum': 'D002945',
#  'etoposide': 'MESH:D005047',
#  'disorientation': 'D003221',
#  'irritability': 'D001523',
#  'coma': 'D003128',
#  'fluoroacetate': 'D005463',
#  'fluorocitrate': 'C007744',
#  'dihydrouracil': 'C007419',
#  'oxcarbazepine': 'C036006',
#  'chlorpromazine': 'D002746',
#  'Erythema': 'D004893',
#  'hypersensitivity': 'D004342',
#  'ampicillin': 'MESH:D000667',
#  'erythema': 'D017445',
#  'gentamicin': 'MESH:D005839',
#  'septicemia': 'D018805',
#  'congestive': 'D006333',
#  'myocarditis': 'D009205',
#  'methylprednisolone': 'D008775',
#  'infections': 'D007239',
#  'Hypersensitivity': 'D004342',
#  'allergy': 'D004342',
#  'penicillins': 'MESH:D010406',
#  'amoxicillin': 'MESH:D019980',
#  'beta-lactam': 'D047090',
#  'AX': 'D000658',
#  'penicillin': 'MESH:D010406',
#  'benzylpenicilloyl-poly-L-lysine': '-1',
#  'BPO-PLL': '-1',
#  'benzylpenicilloate': '-1',
#  'benzylpenicillin': 'D010400',
#  'PG': '9606',
#  'AMP': 'MESH:D000249',
#  'BPO': '-1',
#  'Anaphylaxis': 'D000707',
#  'urticaria': 'D014581',
#  'MDM': 'D007645',
#  'atracurium': 'D001279',
#  'vecuronium': 'D014673',
#  'Atracurium': 'D001279',
#  'benzylisoquinolinium': '-1',
#  'end-stage': 'D007676',
#  'ESRD': 'D007676',
#  'nephrotoxic': 'D007674',
#  'heparan': '6382',
#  'streptozotocin': 'MESH:D013311',
#  'Heparan': 'D006497',
#  'cuprolinic': 'C015445',
#  'glycosaminoglycan': 'DomainMotif',
#  'Diabetic': 'D058065',
#  'albuminuria': 'D000419',
#  'nitrogranulogen': 'D008466',
#  'NG': 'D008466',
#  'MTX': 'MESH:D008727',
#  'CY': 'D003520',
#  'nephrotoxicity': 'D007674',
#  'cognitive': 'D003072',
#  'divalproex': 'D014635',
#  'tremor': 'D014202',
#  'loss': 'D053421',
#  'functional': 'D003072',
#  'cognitive,': 'D003072',
#  'breast': 'D001943',
#  'mitoxantrone': 'D008942',
#  'leucovorin': 'D002955',
#  'MFL': 'C085788',
#  'anthracycline': 'D018943',
#  'vasopressin': '551',
#  'arginine': 'c|Allele|R|714;Gene:2908;Disease:C564221;VariantGroup:0',
#  'AVP': '551',
#  'LiCl': 'D018021',
#  'dehydration': 'D003681',
#  'hyperkalaemia': 'D006947',
#  'suxamethonium': 'D013390',
#  'meningitis': 'D008581',
#  'mepivacaine': 'MESH:D008619',
#  'adrenaline': 'MESH:D004837',
#  'agitation': 'D011595',
#  'incomprehensible': 'D019954',
#  "Dupuytren's": 'D004387',
#  'midazolam': 'D008874',
#  'tacrolimus': 'D016559',
#  'FK506': 'FamilyName',
#  'IgA': '3493',
#  'focal': 'D005923',
#  'PG-9': 'C087567',
#  '3alpha-tropyl': 'C087567',
#  'amnesia': 'D000647',
#  'S-(-)-ET-126': 'C098725',
#  'ACE': '1636',
#  'angiotensin-converting': '1636',
#  'desaturation': 'D001049',
#  'VTE': 'D054556',
#  'OC': 'D003276',
#  'aggressive': 'D010520',
#  'aggressiveness': 'D001523',
#  'Serotonergic': 'D018490',
#  'serotonergic': 'D018490',
#  'venlafaxine': 'D000069470',
#  'sertraline': 'D020280',
#  'Hypotension': 'D007022',
#  'tizanidine': 'C023754',
#  'spasticity': 'D009128',
#  'disorders': 'D002493',
#  'transplant': 'D007674',
#  'TG': '57104',
#  'glomerulopathies': 'D007674',
#  'malignant': 'D018319',
#  'lupus': 'D008181',
#  'Henoch-Schonlein': 'D011695',
#  'endothelial': '10544',
#  'immunologic': 'D007153',
#  'BD1008': 'C085527',
#  'oligodeoxynucleotide': 'D009838',
#  'BD1018': '-1',
#  '3S-1-[2-(3,4-dichlorophenyl)ethyl]-1,4-diazabicyclo[4.3.0]nonane': '-1',
#  'BD1063': 'C093337',
#  '1-[2-(3,4-dichlorophenyl)ethyl]-4-methylpiperazine': 'C093337',
#  'LR132': '-1',
#  'GABA': 'MESH:D005680',
#  'NMDA': '-',
#  'convulsions': 'D012640',
#  'di-o-tolylguanidine': 'C050232',
#  'DTG': 'C050232',
#  'BD1031': '-1',
#  '3R-1-[2-(3,4-dichlorophenyl)ethyl]-1,4-diazabicyclo[4.3.0]nonane': '-1',
#  'convulsive': 'D004829',
#  'E4031': 'C063968',
#  'cisapride': 'D020117',
#  'terfenadine': 'D016593',
#  'terodiline': 'C010637',
#  'Torsades': 'D016171',
#  'TDP': 'D016171',
#  'myeloencephalopathy': 'D001927',
#  'vincristin': 'D014750',
#  'vincristine': 'D014750',
#  'lymphoblastic': 'D054198',
#  'opistothonus,': 'D020258|D020258|D020258',
#  'degeneration': 'D001927',
#  'pseudocystic': '-1',
#  'prochlorperazine': 'D011346',
#  'Antithymocyte': 'D000961',
#  'D-penicillamine': 'D010396',
#  'aplastic': 'D000741',
#  'antithymocyte': 'D000961',
#  'alcohol': 'FamilyName',
#  'ethanol': 'MESH:D000431',
#  'Seizure': 'D012640',
#  'neostigmine': 'D009388',
#  'ACh': 'MESH:D000109',
#  'Potassium': 'D011188',
#  'convulsion': 'D012640',
#  'KCl': 'MESH:D011189',
#  'convulsants': 'D012640',
#  'dexamethasone': 'MESH:D003907',
#  'reduction': 'C565128',
#  'elevated': 'D009798',
#  'Hypertension': 'D006973',
#  'cyproterone': 'D017373',
#  'ethinyl': 'D004997',
#  'Cyproterone': 'D017373',
#  'CPA': 'D017373',
#  'EE': 'D004997',
#  'acne': 'D000152',
#  'hirsutism': 'D006628',
#  'polycystic': 'D007690',
#  'PCOS': 'D011085',
#  'Pseudoacromegaly': 'D004194',
#  'minoxidil': 'D008914',
#  'Acromegaly': 'D000172',
#  'endocrine': 'D004700',
#  'hypertrophy': 'D006984',
#  'cutis': 'C535610',
#  'pseudoacromegaly': 'D004194',
#  'anemia': 'D000740',
#  'prostate': 'D011471',
#  'prostatic': 'D011471',
#  'leuprolide': 'D016729',
#  'LHRH-A': 'D016729',
#  'flutamide': 'D005485',
#  'Testosterone': 'D013739',
#  'dilated': 'D007674',
#  'AmB': 'D000666',
#  'coccidioidomycosis': 'D003047',
#  'posaconazole': 'C101425',
#  'quinine': 'MESH:D011803',
#  'nocturnal': 'D020922',
#  'Organophosphate': 'D010755',
#  'neuropathological': 'D005901',
#  'organophosphorus': 'MESH:D009943',
#  'OP': 'D009943',
#  'diisopropylfluorophosphate': 'D007531',
#  'DFP': 'D007531',
#  'sarin': 'D012524',
#  'soman': 'D012999',
#  'OPs': 'D010755',
#  'pralidoxime-2-chloride': 'D011220',
#  '2PAM': 'D011220',
#  'N(6)-cyclopentyl': 'C048599',
#  'dizocilpine': 'MESH:D016291',
#  'poisoning': 'D011041',
#  'Atropine': 'D001285',
#  'MK801': 'MESH:D016291',
#  'imidazoline': 'D048288',
#  'rilmenidine': 'C032302',
#  '17beta-estradiol': 'D004958',
#  'tincture': 'C007145',
#  'isoproterenol': 'D007545',
#  'Tincture': 'C007145',
#  'TCR': '21473',
#  'alcoholic': 'D006519',
#  'Crataegus': 'C007145',
#  'ADP': 'MESH:D000244',
#  'raloxifene': 'D020849',
#  'tamoxifen': 'D013629',
#  'Raloxifene': 'D020849',
#  'osteoporosis': 'D010024',
#  'cataracts': 'D002386',
#  'gallbladder': 'D005705',
#  'endometrial': 'D016889',
#  'Ceftriaxone': 'D002443',
#  'biliary': 'D001660',
#  'pseudolithiasis': 'D001660',
#  'GNC92H2': '-1',
#  'osteopenia': 'D001851',
#  'amenorrhea': 'D000568',
#  'Ketoconazole': 'D007654',
#  'torsades': 'D016171',
#  'prolonged': 'D008133',
#  'TdP': 'D016171',
#  'fungal': '4651',
#  'long': 'D008133',
#  'extract': 'D010936',
#  'DCE': 'D010936',
#  'Diazepam': 'D003975',
#  'Daucus': '4039',
#  'Cauda': 'D011128',
#  'radiculopathy': 'D011843',
#  'cauda': 'D011128',
#  'triamcinolone': 'C030262',
#  'bupivacaine': 'MESH:D002045',
#  'low': '3949',
#  'numbness': 'D006987',
#  'lower': 'D018908',
#  'neurologic': 'D019636',
#  'testosterone': 'D013739',
#  'estradiol-': 'C032109',
#  'rapamycin': 'D020123',
#  'autoimmunity': 'D001327',
#  'cystic': 'D052177',
#  'statin': 'D019821',
#  'Statins': 'D019821',
#  'hyperCKaemia': '-1',
#  'statins': 'D019821',
#  'necrotic': 'D009336',
#  'cyclic': '12912',
#  'arrhythmia': 'D001145',
#  'Clonidine': 'D003000',
#  'smoking': 'D012906',
#  'Neuroinflammation': 'D007249',
#  'terbutaline': 'D013726',
#  'autism': 'D000067877',
#  'Autism': 'D000067877',
#  'neurodevelopmental': 'D009421',
#  'deficits': 'D001308',
#  'repetitive': 'D001523',
#  'Terbutaline': 'D013726',
#  'preterm': 'C563032',
#  'schizophrenia': 'D012559',
#  'Myocarditis': 'D009205',
#  'psychosis': 'D011605',
#  'Encephalopathy': 'D001927',
#  'levetiracetam': 'D000077287',
#  'valproate': 'D014635',
#  'LEV': 'D000077287',
#  'VPA': 'D014635',
#  'tonic-clonic': 'D004830',
#  'Norepinephrine': 'D009638',
#  'NE': 'D009638',
#  'yohimbine': 'D015016',
#  'attention-deficit/hyperactivity': 'D001289',
#  'methylphenidate': 'D008774',
#  'ADHD': 'D001289',
#  'Drowsiness': 'D006970',
#  'drowsiness': 'D006970',
#  ...}

# %%
species_dct = {}
gene_dct = {}
disease_dct = {}
chemical_dct = {}
variant_dct = {}

with open('data/DrugProt_Train.PubTator') as f:
    lines = [line.rstrip('\n') for line in f]
    for line in lines:
        if len(line.split('\t'))>1:
            if(line.split('\t')[-2]=='Species'):
                species_dct[line.split()[3]] = line.split()[-1]                  
            if(line.split('\t')[-2]=='Gene'):
                gene_dct[line.split()[3]] = line.split()[-1]
            if(line.split('\t')[-2]=='Disease'):
                disease_dct[line.split()[3]] = line.split()[-1]
            if(line.split('\t')[-2]=='Chemical'):
                chemical_dct[line.split()[3]] = line.split()[-1]
            if(line.split('\t')[-2]=='Variant'):
                disease_dct[line.split()[3]] = line.split()[-1]
