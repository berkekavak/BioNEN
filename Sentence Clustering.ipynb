# %%
import os, re
import pandas as pd
from ftfy import fix_text
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans

# %%
s800 = pd.read_csv('data/input/S800-1.0/S800.tsv',sep='\t',header=None)
s800_x = s800[[0,4]].drop_duplicates(subset=4).reset_index(drop=True)

# %%
os.listdir('data/input/')
# Out:
# ['.DS_Store',
#  'S800-1.0 (1).tar.gz',
#  'SPECIES_Train.PubTator',
#  'Linnaeus_Train.PubTator',
#  'BioRED_TrainDev.PubTator',
#  'S800-1.0']

# %%
speciesdct = {}
for file in os.listdir('data/input/'):
    if file.endswith('.PubTator'):
        with open('data/input/' + file) as f:
            lines = [line.rstrip('\n') for line in f]
            for line in lines:
                if ((len(line.split('\t')) > 1)):
                    if((line.split('\t')[4] == 'Species')):
                         speciesdct[line.split('\t')[3]] = line.split('\t')[-1]

# %%
s800_x
# Out:
#            0                         4
# 0       5833     Plasmodium falciparum
# 1       5833              P falciparum
# 2       4929    Candida guilliermondii
# 3       4932                     yeast
# 4       4929         C. guilliermondii
# ...      ...                       ...
# 1498   49186  Marinobacterium stanieri
# 1499  693965               LMG 25435(T
# 1500  693965              CAIM 1449(T)
# 1501    4236                   lettuce
# 1502    8030               Salmo salar
#
# [1503 rows x 2 columns]

# %%
list(s800[4].unique())
# Out:
# ['Plasmodium falciparum',
#  'P falciparum',
#  'Candida guilliermondii',
#  'yeast',
#  'C. guilliermondii',
#  'Tuber melanosporum',
#  'T. melanosporum',
#  'Aspergillus nidulans',
#  'D. derouxi',
#  'Geleia sinica spec. nov.',
#  'K. flavus',
#  'K. gracilis',
#  'Geleia simplex (Faure-Fremiet, 1951)',
#  'Kentrophoros flavus Raikov and Kovaleva, 1968',
#  'Kentrophoros gracilis Raikov, 1963',
#  'tobacco',
#  'Neisseria gonorrhoeae',
#  'Neisseria meningitidis',
#  'meningococcal',
#  'black-legged kittiwake',
#  'Aspergillus fumigatus',
#  'Candida albicans',
#  'Norway spruce',
#  'Picea abies',
#  'Leuciscus leuciscus',
#  'Solanum lycopersicum',
#  'tomato',
#  'potato',
#  'Dunaliella tertiolecta',
#  'Pelargonium x hortorum',
#  'barley',
#  'Arabidopsis thaliana',
#  'Lolium perenne',
#  'Cotterillia bromelicola nov. gen., nov. spec.',
#  'Tillandsia heterophylla',
#  'Cotterillia',
#  'Cotterillia bromelicola',
#  'Spodoptera litura Fabricius',
#  'S. litura',
#  'Rana limnocharis',
#  'Oramoeba fumarolia',
#  'Stachyamoeba sp. ATCC50324',
#  'Vrihiamoeba italica',
#  'rice',
#  'C. albicans',
#  'Saccharomyces cerevisiae',
#  'influenza A H1N1',
#  'influenza A viruses',
#  'influenza A',
#  'Newcastle disease virus',
#  'chicken',
#  'NDV',
#  'poultry',
#  'peach',
#  'Blastomyces dermatitidis',
#  'Chaetomium globosum',
#  'Cryptococcus neoformans',
#  'C. neoformans',
#  'serotype A',
#  'serotype D C. neoformans',
#  'Ustilago maydis',
#  'Bythotrephes longimanus',
#  'Holopedium gibberum',
#  'oaks',
#  'Quercus robur',
#  'maize',
#  'Diabrotica virgifera',
#  'Zea mays',
#  'Spodoptera littoralis',
#  'S. littoralis',
#  'Neurospora crassa',
#  'A. nidulans',
#  'N. crassa',
#  'brown trout',
#  'Salmo trutta',
#  'roundhead galaxias',
#  'Galaxias anomalus',
#  'native galaxias',
#  'trout',
#  'galaxias',
#  'blue tits',
#  'Plasmodium relictum',
#  'P. circumflexum',
#  'Tiaris bicolor',
#  'Coereba flaveola',
#  'Loxigilla noctis',
#  'barbadensis',
#  'Maize mosaic rhabdovirus',
#  'Peregrinus maidis',
#  'corn planthopper',
#  'Maize mosaic rhabdovirus (MMV)',
#  'MMV',
#  'P. maidis',
#  'brown planthopper',
#  'Nilaparvata lugens',
#  'Ni. lugens',
#  'Acyrthosiphon pisum',
#  'Megaphorura arctica',
#  'Arctic springtail',
#  'M. arctica',
#  'Trichoplusia ni',
#  'Bombyx mori',
#  'B. mori',
#  'T. ni',
#  'Tetranychus urticae',
#  'Eichhornia crassipes',
#  'E. crassipes',
#  'blue-footed boobies',
#  'blue-footed booby',
#  'Sula nebouxii',
#  'Amnibacterium kyonggiense gen. nov., sp. nov.',
#  'KSL51201-037(T)',
#  'Labedella gwakjiensis KSW2-17(T)',
#  'Leifsonia ginsengi wged11(T)',
#  'Microterricola viridarii KV-677(T)',
#  'Methanobacterium petrolearium sp. nov.',
#  'Methanobacterium ferruginis sp. nov.',
#  'Methanobacterium subterraneum',
#  'Jiangella muralis sp. nov.',
#  '15-Je-017(T)',
#  'Jiangella alba YIM 61503(T)',
#  'Jiangella alkaliphila D8-87(T)',
#  'Jiangella gansuensis YIM 002(T)',
#  'Miniimonas arenae',
#  'YM18-15',
#  'Serinibacter salmoneus',
#  'Salana multivorans',
#  'Beutenbergia cavernae',
#  'Debaryomyces hansenii',
#  'D. hansenii',
#  'Nocardioides caricicola sp. nov.',
#  'Carex scabrifolia',
#  'YC6903',
#  'Nocardioides pyridinolyticus OS4',
#  'Nocardioides dokdonensis FR1436',
#  'Nocardioides aquiterrae GW-9',
#  'Nocardioides hankookensis DS-30',
#  'N. pyridinolyticus OS4',
#  'Spirochaeta litoralis',
#  'S. isovalerica',
#  'S. cellobiosiphila',
#  'Clostridiisalibacter paucivorans',
#  'Thermohalobacter berrensis',
#  'Caloranaerobacter azorensis',
#  'Escherichia coli',
#  'Pseudomonas aeruginosa',
#  'Bacillus subtilis',
#  'Penicillium citrinum',
#  'Streptomyces morookaense',
#  'ATCC 19166(T)',
#  'Streptomyces lavenduligriseus',
#  'ATCC 13306(T)',
#  'S. morookaense',
#  'Candida glabrata',
#  'Candida krusei',
#  'HIV',
#  'human',
#  'elephant',
#  'African elephant',
#  'Elephant',
#  'Colophospermum mopane',
#  'C. mopane',
#  'American alligators',
#  'Alligator mississippiensis',
#  'African striped mouse',
#  'Rhabdomys pumilio',
#  'Staphylococcus aureus',
#  'newman',
#  'UAMS-1',
#  'Newman',
#  'S. aureus',
#  'durum wheat',
#  'Triticum durum',
#  'Florida panthers',
#  'Puma concolor coryi',
#  'P. c. stanleyana',
#  'Bacillus thuringiensis var. israelensis',
#  'Musca domestica',
#  'house flies',
#  'Bacillus thuringiensis variety israelensis',
#  'Bti',
#  'M. domestica',
#  'chickens',
#  'Fusarium verticillioides',
#  'F. verticillioides',
#  'F. oxysporum',
#  'F. graminearum',
#  'corn',
#  'Phaseolus vulgaris',
#  'sunflower',
#  'Helianthus annuus',
#  'Eimeria nieschulzi',
#  'Eimeria falciformis',
#  'Arctic charr',
#  'Salvelinus alpines',
#  "charr's",
#  'charr',
#  'Mauritius kestrel',
#  'Phytophthora sojae',
#  'soybean',
#  'Colorado potato beetle',
#  'Leptinotarsa decemlineata (Say)',
#  'plum curculio',
#  'Conotrachelus nenuphar (Herbst)',
#  'western corn rootworm',
#  'Diabrotica virgifera virgifera (LeConte)',
#  'Colorado potato beetles',
#  'plum curculios',
#  'western corn rootworms',
#  'poplar leaf beetle',
#  'Chrysomela tremulae',
#  'C. tremulae',
#  'Bacillus thuringiensis',
#  'Bt',
#  'Theobroma Cacao',
#  'cacao',
#  'Theobroma cacao',
#  'Serratia marcescens',
#  'S. marcescens',
#  'hihi',
#  'Notiomystis cincta',
#  'humans',
#  'Aedes aegypti',
#  'Sindbis',
#  'SINV',
#  'Sitophilus zeamais',
#  'maize weevil',
#  'S. zeamais',
#  'A. fumigatus',
#  'garter snake',
#  'Thamnophis elegans',
#  'corn smut',
#  'U. maydis',
#  'Botryotinia fuckeliana',
#  'white-footed mice',
#  'Peromyscus leucopus',
#  'Borrelia burgdorferi',
#  'White-footed mice',
#  'rice blast pathogen',
#  'Magnaporthe oryzae',
#  'M.oryzae',
#  'M. oryzae',
#  'ATMT0225B6',
#  'MoCDC15(T-DNA)',
#  'wild type MoCDC15',
#  'Glomus intraradices',
#  'G. intraradicesNH(4)',
#  'Yeast',
#  'Aspergillus fumigatuscyp51A',
#  'red-backed shrike',
#  'Lanius collurio',
#  'N. meningitidis',
#  'rabbit',
#  'Burkholderia cenocepacia',
#  'Rhizoctonia solani',
#  'Aeromonas hydrophila',
#  'Mycobacterium tuberculosis',
#  'M. tuberculosis',
#  'M. smegmatis',
#  'Rhizobium sp. strain LPU83',
#  'alfalfa',
#  'Leucena leucocephala',
#  'Sinorhizobium meliloti',
#  'Sinorhizobium medicae',
#  'Rhizobium mongolense USDA 1844',
#  'LPU83',
#  'R. mongolense 1844',
#  'LPU83-H',
#  'Bacillus amyloliquefaciens FZB42',
#  'B. amyloliquefaciens FZB42',
#  'strain Bacillus subtilis YB955 (hisC952 metB5 leuC427)',
#  'MutSL knockout strain',
#  'B. subtilis',
#  'Clostridium difficile',
#  'C. difficile',
#  'Bacillus anthracis',
#  'B. anthracis',
#  'anthrax',
#  'B. anthracis strain',
#  'mouse',
#  'Pseudomonas fluorescens Q8r1-96',
#  'Q8r1-96',
#  'Pseudomonas syringae',
#  'P. fluorescens strains',
#  'P. syringae',
#  'Helicobacter pylori',
#  'Porphyromonas gingivalis',
#  'P. gingivalis',
#  'Synechocystis sp. strain PCC 6803',
#  'Diplonema papillatum',
#  'D. papillatum',
#  'P. penardii',
#  'P. niei',
#  'sycamore lace bug',
#  'Corythucha ciliata',
#  'C. ciliata',
#  'London plane tree',
#  'Platanus x acerifolia',
#  'Zea mays (L.)',
#  'Sorghum bicolor (L.)',
#  'Cotesia sesamiae (Cameron)',
#  'C. flavipes Cameron',
#  'New World screw-worm',
#  'Cochliomyia hominivorax',
#  'C. hominivorax',
#  'Soybean dwarf virus',
#  'SbDV',
#  'Bean leafroll virus',
#  'BLRV',
#  'Beet chlorosis virus',
#  'BChV',
#  'Beet mild yellowing virus',
#  'BMYV',
#  'Beet western yellows virus',
#  'BWYV',
#  'Cereal yellow dwarf virus-RPV',
#  'CYDV-RPV',
#  'Cucurbit aphid-borne yellows virus',
#  'CABYV',
#  'Potato leafroll virus',
#  'PLRV',
#  'Turnip yellows virus',
#  'TuYV',
#  'canine',
#  'Tremula longifila',
#  'Micrometopion nutans',
#  'Minimassisteria diva',
#  'Peregrinia clavideferens',
#  'Nudifila producta',
#  'Ovulinata parva',
#  'Chlorella minutissima',
#  'Chlorella strains',
#  'Tetrahymena canadensis',
#  'Tetrahymena hegewischi',
#  'Tetrahymena pyriformis',
#  'Tetrahymena rostrata',
#  'Tetrahymena thermophila',
#  'Tetrahymena tropicalis',
#  'Nothofagus pumilio',
#  'N. pumilio',
#  'Arabidopsis',
#  'Potato leaf roll virus',
#  'Turnip mosaic virus',
#  'leafminer',
#  'Liriomyza huidobrensis',
#  'wasp',
#  'Opius dissitus',
#  'wild-type (WT) plant',
#  'JA biosynthesis (spr2) mutant',
#  'JA-overexpression 35S::prosys plant',
#  'leafminers',
#  'spr2 mutant plants',
#  'WT plants',
#  '35S::prosys plant',
#  'bread wheat',
#  'wheat',
#  'sugarcane',
#  'Saccharum spp.',
#  'S. officinarum',
#  'S. spontaneum',
#  'Omegastrombidium elegans',
#  'A. thaliana',
#  'Oryza sativa',
#  'Oryza sativa short postembryonic roots 1',
#  'Osspr1',
#  'OsSPR1',
#  'yeasts',
#  'Botrytis cinerea',
#  'Bathygobius fuscus',
#  'Chaenogobius annularis',
#  'C. gulosus',
#  'B. fuscus',
#  'Chromera velia',
#  'C. velia',
#  'duck astrovirus',
#  'Duck astrovirus',
#  'DAstV',
#  'duck hepatitis A virus',
#  'duck plague herpesvirus',
#  'duck reovirus',
#  'Riemerella anatipestifer 12/19',
#  '26/51',
#  'redshank',
#  'Tringa totanus',
#  'Eurasian sparrowhawks',
#  'Accipiter nisus',
#  'Sparrowhawk',
#  'redshanks',
#  'Redshanks',
#  'Myrmica rubra',
#  'Lasius niger',
#  'M. rubra',
#  'L. niger',
#  'common cuckoos',
#  'Cuculus canorus',
#  'cuckoo',
#  'cuckoos',
#  'Pichiapastoris',
#  'Schizosaccharomyces pombe',
#  'housefly',
#  'Sarcophaga crassipalpis',
#  'Entodinium caudatum',
#  'Eudiplodinium maggii',
#  'Epidinium ecaudatum',
#  'E. caudatum',
#  'E. maggii',
#  'E. ecaudatum',
#  'Turk rahvan horse',
#  'Equus caballus',
#  'Turk rahvan horses',
#  'horses',
#  'Beauveria bassiana',
#  'corn leafhopper',
#  'Dalbulus maidis',
#  'Delphacodes kuscheli',
#  'D. maidis',
#  'D. kuscheli',
#  'B. bassiana',
#  'B. mycoides',
#  'B. megaterium',
#  'B.pumilus',
#  'B. licheniformis',
#  'Solenopsis invicta',
#  'Hymenoptera',
#  'Heliconius erato',
#  'H. erato',
#  'Phaeodactylum tricornutum',
#  'P. tricornutum',
#  'Almophrya bivacuolata',
#  'Eudrilophrya complanata',
#  'Metaracoelophrya intermedia',
#  'Njinella prolifera',
#  'Paraclausilocola constricta n. gen., n. sp.',
#  'Paraclausilocola elongata n. sp.',
#  'West Nile',
#  'WN virus',
#  'Japanese encephalitis virus',
#  'WN',
#  'WNV',
#  'JEV',
#  'Parasterkiella thompsoni',
#  'P. thompsoni',
#  'Sterkiella thompsoni',
#  'orf virus',
#  'ORFV',
#  'Aspergillus terreus',
#  'Aspergillus niger',
#  'A. terreus',
#  'human body lice',
#  'body lice',
#  'retroviral',
#  'murine leukemia virus (F-MuLV)',
#  'transmissible gastroenteritis virus',
#  'TGEV',
#  'severe acute respiratory syndrome coronavirus',
#  'white-throated dipper',
#  'Cinclus cinclus',
#  'influenza A virus',
#  'influenza',
#  'A/Duck/Hubei/L-1/2004 (H5N1) virus',
#  'H5N1',
#  'swine-origin influenza A virus (S-OIV) (H1N1)',
#  'human adenovirus',
#  'Human adenoviruses (Ads)',
#  'adenovirus',
#  'adenoviral',
#  'Fusarium graminearum',
#  'Blumeria graminis f. sp. tritici',
#  'B.g. tritici',
#  'hordei',
#  'B.g. hordei',
#  'influenza virus',
#  'hepatitis C virus',
#  'Nicotiana benthamiana',
#  'Potato virus X',
#  'PVX',
#  'silkmoth',
#  'honeybees',
#  'Apis mellifera',
#  'Honeybees',
#  'Africanized honeybees',
#  'bean bug',
#  'Riptortus pedestris',
#  'Perkinsus marinus',
#  'T4',
#  'foot-and-mouth disease virus O',
#  'A',
#  'Asia 1',
#  'foot-and-mouth disease virus',
#  'FMDV',
#  'O',
#  'rabbits',
#  'O/CHA/99',
#  'A/GS/LX/66',
#  'Asia 1/CHN/05',
#  'O/AV99(L)',
#  'A/AV88(L)',
#  'Asia 1/YNBS/58',
#  'FMDV type Asia 1',
#  'pandemic influenza virus',
#  'Influenza A virus',
#  'Aspergillus oryzae',
#  'Aspergillus flavus',
#  'A. oryzae',
#  'A. flavus',
#  'Asian rice gall midge',
#  'Orseolia oryzae',
#  'Eupolyphaga sinensis',
#  'E. sinensis',
#  'Polysphondylium pallidum',
#  'H. nuttallii',
#  'H. pauciflorus',
#  'H. petiolaris',
#  'H. annuus',
#  'Glassy-Winged Sharpshooter',
#  'Homalodisca vitripennis',
#  'glassy-winged sharpshooter',
#  'Homalodisca vitripennis (Germar)',
#  'H. vitripennis',
#  'Xylella fastidiosa (Wells)',
#  'Nicotiana rustica',
#  'Glomus etunicatum',
#  'silver leaf whitefly',
#  'Bemisia argentifolii',
#  'Eretmocerus eremicus',
#  'Grapholita molesta',
#  'Peach',
#  'Prunus persica (L.) Batcsh',
#  'oriental fruit moth',
#  'Grapholita molesta (Busck)',
#  'G. molesta',
#  'Trichogramma minutum (Riley)',
#  'apple',
#  'Venturia inaequalis',
#  'Spilocaea pomi',
#  'V. inaequalis',
#  'Malus baccata jackii',
#  'M. micromalus',
#  'Metarhizium brunneum',
#  'M. brunneum',
#  'greater wax moth',
#  'Galleria mellonella',
#  'Pseudacteon tricuspis',
#  'P. tricuspis',
#  'Tribolium castaneum',
#  'Tribolium castaneum (Herbst)',
#  'T. castaneum',
#  'stable fly',
#  'Spalangia cameroni',
#  'Spalangia endius',
#  'Muscidifurax raptorellus',
#  'M. raptorellus',
#  'S. cameroni',
#  'S. endius',
#  'swine',
#  'H1N1 viruses',
#  'swine-origin influenza A (H1N1) virus',
#  'H9N2 virus',
#  'A/turkey/OH/313053/04 (H3N2)',
#  'H1N1',
#  'Elatobium abietinum',
#  'Sitka spruce',
#  'E. abietinum',
#  'Bemisia tabaci',
#  'sweetpotato whitefly',
#  'B. tabaci',
#  'Trialeurodes vaporariorum',
#  'T. vaporariorum',
#  'cotton',
#  'varicella-zoster virus',
#  'VZV',
#  'VZV-induced',
#  'Odontoglossum ringspot virus',
#  'ORSV',
#  'cabbage',
#  'Mexican palo verde',
#  'Parkinsonia aculeata',
#  'Platynota stultana',
#  'P. aculeata',
#  'silkworm',
#  'Silkworm',
#  'Bombyx mori L',
#  'Heliothis virescens',
#  'Mygona irmina',
#  'Chusquea c.f. scandens',
#  'great tits',
#  'Parus major L.',
#  'Toxoneuron nigriceps',
#  'T. nigriceps',
#  'tobacco budworm',
#  'Tenebrio molitor',
#  'Metarhizium anisopliae',
#  'lsaria (=Paecilomyces) sp.',
#  'M. anisopliae',
#  'Cuban laurel thrips',
#  'greenhouse whitefly',
#  'European corn borer',
#  'Ostrinia nubilalis',
#  "Marek's disease virus type 1",
#  "Marek's disease virus 1",
#  'MDV1',
#  'human lice',
#  'lethal 2009 pandemic H1N1 influenza virus',
#  'H1N1 influenza',
#  '2009 pandemic virus',
#  'H1',
#  'H3 influenza virus',
#  '2009 H1N1 A/CA/04/09 virus',
#  'pandemic H1N1 influenza virus',
#  'Dermamoeba algensis n. sp.',
#  'D. algensis n. sp.',
#  'D. algensis',
#  'S aureus',
#  'HIV-1',
#  'Campylobacter fetus subsp. venerealis',
#  'Campylobacter fetus',
#  'Campylobacter coli',
#  'C. fetus',
#  'C. fetus subsp. venerealis',
#  'Serinicoccus profundi sp. nov.',
#  'MCCC 1A05965',
#  'Serinicoccus marinus',
#  'Serinicoccus profundi sp. nov',
#  'human immunodeficiency virus type 1',
#  'Poliovirus',
#  'poliovirus',
#  'rat cytomegalovirus',
#  'RCMV',
#  'mouse cytomegalovirus',
#  'mice',
#  'human cytomegalovirus',
#  'herpes simplex virus type 1',
#  "Kaposi's sarcoma herpesvirus",
#  'HCMV',
#  'Epstein-Barr virus',
#  'EBV',
#  'SARS-CoV',
#  'Venezuelan equine encephalitis virus',
#  'VEE',
#  'West Nile virus',
#  'HCV',
#  'anti-HCV',
#  'Mammalian orthoreoviruses',
#  'Chikungunya virus',
#  'CHIKV',
#  'Vesicular stomatitis virus',
#  'VSV',
#  'Varicella-zoster virus',
#  'Lassa virus',
#  'Lassa virus AV',
#  'Human immunodeficiency virus type 1',
#  'Mice',
#  'hepatitis B virus',
#  'HBV',
#  'PV',
#  'H5N1 viruses',
#  "Theiler's murine encephalitis virus",
#  'TMEV',
#  'simian immunodeficiency virus',
#  'Human immunodeficiency virus',
#  'Indian rhesus macaques',
#  'virus SIVmac239',
#  'SIV',
#  'Tischeria ekebladella',
#  'T. ekebladella',
#  'dengue virus',
#  'dengue viruses',
#  'Dengue',
#  'dengue',
#  'SIVagmTan-1',
#  'Retroviral',
#  'SIV(agmTan-1)',
#  'hepatitis B',
#  'hepatitis delta viruses',
#  'Hepatitis B virus',
#  'hepatitis delta virus',
#  'HDV',
#  'Hepatitis C virus',
#  'Oscillochloris trichoides subsp. DG-6',
#  'Oscillochloris trichoides',
#  'Baetis rhodani',
#  'B. rhodani',
#  'root voles',
#  'Microtus oeconomus',
#  'Chlorella vulgaris',
#  'Paramecium bursaria',
#  'P. bursaria',
#  'Flavobacterium frigoris LMG 21922(T)',
#  'Flavobacterium terrae R2A1-13(T)',
#  'Flavobacterium gelidilacus LMG 21477(T)',
#  'broccoli',
#  'Brassica oleracea var. italica',
#  'Nicotiana tabacum',
#  'Poterioochromonas malhamensis',
#  'P. malhamensis',
#  'fungal',
#  'Medicago truncatula',
#  'Daucus carota',
#  'M. truncatula',
#  'Ginkgo biloba',
#  'G. biloba',
#  'morels',
#  'Morchella rufobrunnea',
#  'black morels',
#  'yellow morels',
#  'Morels',
#  'Crithidia deanei',
#  'C. desouzai',
#  'Crithidia oncopelti',
#  'Blastocrithidia culicis',
#  'human adenoviruses',
#  'JC polyomaviruses',
#  'coxsackievirus B3',
#  'CVB3',
#  'pandemic influenza A/H1N1 2009',
#  'seasonal influenza A/H1N1',
#  'seasonal influenza A/H3N2 viruses',
#  'Pandemic influenza A/H1N1 2009 (A/H1N1pdm) virus',
#  'A/H1N1pdm virus',
#  'seasonal A/H1N1',
#  'A/H3N2 influenza viruses',
#  'viral strains of A/H1N1pdm',
#  'A/Aichi/472/2009 (H1N1)pdm',
#  'A/Sakai/89/2009 (H1N1)pdm',
#  'A/H1pdm',
#  'A/H3',
#  'A/H1',
#  'influenza viruses',
#  'Pichia membranifaciens',
#  'S. cerevisiae',
#  'infectious myonecrosis virus',
#  'IMNV',
#  'BL21 E. coli',
#  'white spot syndrome virus',
#  'WSSV',
#  'yellow head virus',
#  'YHV',
#  'Taura syndrome virus',
#  'TSV',
#  'Penaeus monodon nucleopolyhedrovirus',
#  'PemoNPV',
#  'sheep poxvirus',
#  'SPPV',
#  'goat poxvirus',
#  'GTPV',
#  'lumpy skin disease virus',
#  'LSDV',
#  'sheep',
#  'goats',
#  'cattle',
#  'goatpox',
#  'sheeppox viruses',
#  'serotype A foot-and-mouth disease virus',
#  'FMD',
#  'Lucilia sericata',
#  'Drosophila melanogaster',
#  'Drosophila',
#  'L. sericata',
#  'D. melanogaster',
#  'Perigord black truffle',
#  'Auritidibacter ignavus gen. nov., sp. nov.',
#  'IMMIB L-1656(T)',
#  'Auritidibacter ignavus',
#  'DSM 45359(T)',
#  'CCUG 57943(T)',
#  'porcine endogenous retrovirus',
#  'Porcine endogenous retroviruses',
#  'PERVs',
#  'pigs',
#  'PERV',
#  'PERV-B',
#  'PERV-A',
#  'grey-crowned babbler',
#  'Pomatostomus temporalis',
#  'grey-crowned babblers',
#  'Plasmodiophora brassicae',
#  'Spongospora subterranea',
#  'Brassica rapa',
#  'Solanum tuberosum',
#  'S. subterranea',
#  'L. chlorophorum',
#  'Hortaea werneckii',
#  'S. cerevisae',
#  'H. werneckii',
#  'Coprinopsis cinerea',
#  'Streptococcus pneumoniae',
#  'S. pneumoniae',
#  'Leavenworthia crassa',
#  'L. crassa',
#  'Lotus creticus',
#  'Lotus corniculatus',
#  'Lotus tenuis',
#  'L. creticus',
#  'type A H1N1',
#  'type B human influenza virus',
#  'type B influenza viruses',
#  'Coxsackievirus A16',
#  'CA16',
#  'pea aphid',
#  'Serratia symbiotica',
#  'pea aphids',
#  'S. symbiotica',
#  'Apis cerana cerana',
#  'Apis cerana cerana (Acc)',
#  'worker honeybees',
#  'Fagus sylvatica',
#  'European beech',
#  'cucumber',
#  'honey bee',
#  'honey bees',
#  'Agrobacterium tumefasciens',
#  'Blastocladiella emersonii',
#  'Agrobacterium tumefaciens',
#  'Agrobacterium tumefsciens',
#  'Penicillium chrysogenum',
#  'Strains G203R-T',
#  'Deltapga1',
#  'strains with the pga1(G42R) allele',
#  'strains with an active Pga1',
#  'yellow fever mosquito',
#  'Ae. aegypti',
#  'Neurosporacrassa',
#  'Gryllus bimaculatus',
#  'Gryllus bimaculatus DeGeer',
#  'Enterococcus faecium',
#  'E. faecium E1162',
#  'E1162',
#  'E. faecium',
#  'Paramecium caudatum',
#  'P. aeruginosa',
#  'P. aeruginosa strain PA103',
#  'Streptococcus suis',
#  'S. suis strain 89/1591',
#  'Pinus sylvestris',
#  'Eciton burchellii',
#  'Alces alces',
#  'vaccinia virus',
#  'VV',
#  'Aeropyrum pernix',
#  'Sulfolobus solfataricus',
#  'Achromobacter xylosoxidans A8',
#  'Achromobacter xylosoxidans strain A8',
#  'A. xylosoxidans',
#  'Shigella boydii',
#  'Chlamydia trachomatis',
#  'E. coli',
#  'K-12 strain',
#  'B strain',
#  'methanogenic archaea',
#  'Methanocaldococcus jannaschii',
#  'Methanothermobacter thermoautotrophicus',
#  'Methanosarcina acetivorans',
#  'Methanococcus maripaludis',
#  'M. acetivorans',
#  'M. maripaludis',
#  'Human cytomegalovirus',
#  'Hepatitis delta virus',
#  'hepatitis D',
#  'bacteriophage',
#  'Human',
#  'Sordaria macrospora',
#  'S. macrospora',
#  'Fusarium graminearum complex',
#  'FGSC',
#  'FGSC species',
#  'Fusarium nepalense',
#  'Fusarium ussurianum+Fusarium asiaticum',
#  'Fusarium louisianense',
#  'Fusarium gerlachii+F. graminearum',
#  'F. nepalense',
#  'F. louisianense',
#  'moose',
#  'Ploesoma hudsoni',
#  'Colpoda cucullus',
#  'great tit',
#  'Parus major',
#  'Paramecium pentaurelia',
#  'P. pentaurelia',
#  'porcine circovirus type 2',
#  'porcine circovirus type 2 (PCV2)',
#  'pig',
#  'A. niger',
#  'narcissus bulb fly',
#  'Merodon equestris',
#  'house fly',
#  'Glossinia pallidipes',
#  'P. brassicae',
#  'Gymnodinium myriopyrenoides',
#  'G. myriopyrenoides',
#  'Amphidinium poecilochroum',
#  'Gymnodinium acidotum',
#  'respiratory syncytial virus',
#  'human metapneumovirus',
#  'human bocavirus',
#  'Proteus mirabilis',
#  'P. mirabilis',
#  'Ammophila arenaria',
#  'A. arenaria',
#  'Metallosphaera sedula',
#  'Callosobruchus maculatus',
#  'Chlamydomonas reinhardtii',
#  'Casaurina glauca',
#  'Datisca glomerata',
#  'S. meliloti',
#  'Cephalanthera damasonium',
#  'C. damasonium',
#  'Paracercomonas marina',
#  'Paulinella chromatophora',
#  'Filoreta japonica',
#  'Cronartium quercuum f.sp. fusiforme',
#  'loblolly pine',
#  'Fusarium graminearum species complex',
#  'Fusariumboothii',
#  'F. boothii',
#  'Amylostereum areolatum',
#  'A. areolatum',
#  'northern house mosquito',
#  'Culex pipiens',
#  'C. pipiens',
#  'Amoebophrya sp.',
#  'Scrippsiella trochoidea',
#  'Amoebophrya spp.',
#  'Aspergillus parasiticus',
#  'diamondback moth',
#  'DBM',
#  'Plutella xylostella',
#  'Barbarea vulgaris',
#  'Cyanidioschyzon merolae',
#  'rat',
#  'Phytophthora nicotianae',
#  'Ochromonas danica',
#  'Aureococcus anophagefferens',
#  'Scytosiphon lomentaria',
#  'Thalassiosira pseudonana',
#  'T. weissflogii',
#  'P. caudatum',
#  'ring ouzel',
#  'Turdus torquatus',
#  'coho salmon',
#  'steelhead trout',
#  'steelhead',
#  'coho',
#  'brook trout',
#  'Atlantic salmon',
#  'tawny owls',
#  'Formica aquilonia',
#  'F. aquilonia',
#  'Camponotus herculeanus',
#  'white spruce',
#  'Picea glauca',
#  '[Picea glauca (Moench) Voss]',
#  'Populus trichocarpa x deltoides',
#  'Populus trichocarpa',
#  'Larrea tridentata',
#  'L. tridentata',
#  'Klebsiella pneumoniae',
#  'Medicago sativa',
#  'Triticum aestivum',
#  'Asian rice',
#  'Oryza rufipogon',
#  'tropical japonica rice',
#  'citrus red mite',
#  'Panonychus citri',
#  'P. citri',
#  'green turtles',
#  'Chelonia mydas',
#  'Gibberella zeae',
#  'chamois',
#  'Rupicapra rupicapra',
#  'Artemisia annua plants',
#  'A. annua',
#  'A. annua plants',
#  'N. tetrasperma',
#  'Neurospora tetrasperma',
#  'Leptogium saturninum',
#  'Auricularia auricula-judae',
#  'Penicillium marneffei',
#  'Neosartorya fischeri',
#  'Metaphycus luteolus',
#  'M. luteolus',
#  'Bombus terrestris',
#  'B. terrestris',
#  'Anopheles gambiae',
#  'Anopheles quadrimaculatus',
#  'An. gambiae',
#  'Klebsormidium flaccidum',
#  'K. subtilissimum',
#  'Stichococcus bacillaris',
#  'S. chloranthus',
#  'Pirum gemmata gen. nov., sp. nov.',
#  'Abeoforma whisleri, gen. nov., sp. nov.',
#  'Pirum gemmata',
#  'Abeoforma whisleri',
#  'A. whisleri',
#  'P. gemmata',
#  'Pieris brassicae',
#  'H. virescens',
#  'Hv',
#  'Heliothis subflexa',
#  'Hs',
#  ...]

# %%
def ngrams(string, n=3):
    string = str(string)

    # Fixes text for any possible decoding issues
    string = fix_text(string)

    # Removes non ascii chars
    string = string.lower()
    string = string.encode("ascii", errors="ignore").decode()

    # Cleaning unrelevant characters
    chars_to_remove = [")","(",".","|","[","]","{","}","'"]
    rx = '[' + re.escape(''.join(chars_to_remove)) + ']'
    string = re.sub(rx, '', string)
    string = string.replace('&', 'and')
    string = string.replace(',', ' ')
    string = string.replace('-', ' ')
    string = string.title()
    string = re.sub(' +',' ',string).strip()
    string = ' '+ string +' '
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
vectorizer = TfidfVectorizer(min_df=1, analyzer=ngrams, lowercase=False)

# %%
tfidf = vectorizer.fit_transform(list(s800[4].unique()))

# %%
tfidf
# Out:
# <1503x4625 sparse matrix of type '<class 'numpy.float64'>'
# 	with 23924 stored elements in Compressed Sparse Row format>

# %%
kmeans = KMeans(n_clusters=2, random_state=0, n_init="auto").fit_predict(tfidf)

# %%
import time
# Create the kNN-model and learn from TF-IDF matrix
nbrs = NearestNeighbors(n_neighbors=1, n_jobs=-1).fit(tfidf)
unique_org = s800_x[4].values.astype('U').tolist()

# We will use the Eucledian distance (which is default) of two TF-IDF matrices.
def getNearestN(query):
    # Returns a number document-term matrix
    queryTFIDF_ = vectorizer.transform(query) 
    distances, _ = nbrs.kneighbors(queryTFIDF_)
    return distances, _

start_time = time.time()
distances, _ = getNearestN(unique_org)
t = time.time() - start_time
print("Completed in:", t)
# Out:
# Completed in: 0.11319494247436523

# %%
s800 = s800_x.rename(columns={4:'index'})

# %%
spec = pd.DataFrame.from_dict(speciesdct, orient='index').reset_index()

# %%
final = pd.concat([s800, spec])

# %%
final = final.drop_duplicates(subset=['index']).reset_index(drop=True)

# %%
train = final.head(100)

# %%
train
# Out:
#           0                   index
# 0      5833   Plasmodium falciparum
# 1      5833            P falciparum
# 2      4929  Candida guilliermondii
# 3      4932                   yeast
# 4      4929       C. guilliermondii
# ..      ...                     ...
# 95   108931              Ni. lugens
# 96     7029     Acyrthosiphon pisum
# 97  1071257     Megaphorura arctica
# 98  1071257       Arctic springtail
# 99  1071257              M. arctica
#
# [100 rows x 2 columns]

# %%
# s = pd.DataFrame(columns=['S1','S2'])

# count = 0
# for x in train['index']:
#     for y in train['index']:
#         s.loc[count, "S1"] = x
#         s.loc[count, "S2"] = y
#         count += 1

# %%
import pandas as pd
from itertools import product

train_index = train['index']

s = pd.DataFrame(list(product(train_index, train_index)), columns=['S1', 'S2'])

# %%
s
# Out:
#                          S1                      S2
# 0     Plasmodium falciparum   Plasmodium falciparum
# 1     Plasmodium falciparum            P falciparum
# 2     Plasmodium falciparum  Candida guilliermondii
# 3     Plasmodium falciparum                   yeast
# 4     Plasmodium falciparum       C. guilliermondii
# ...                     ...                     ...
# 9995             M. arctica              Ni. lugens
# 9996             M. arctica     Acyrthosiphon pisum
# 9997             M. arctica     Megaphorura arctica
# 9998             M. arctica       Arctic springtail
# 9999             M. arctica              M. arctica
#
# [10000 rows x 2 columns]

# %%
tfidf = vectorizer.fit_transform(s['S1'])
nbrs = NearestNeighbors(n_neighbors=1, n_jobs=-1).fit(tfidf)

# %%
def getNearestN(query):
    # Returns a number document-term matrix
    queryTFIDF_ = vectorizer.transform(query) 
    distances, _ = nbrs.kneighbors(queryTFIDF_)
    return distances, _

start_time = time.time()
distances, _ = getNearestN(s['S2'])
t = time.time() - start_time

# %%
s.insert(2,'Distance',distances, True)

# %%
s
# Out:
#                          S1                      S2      Distance
# 0     Plasmodium falciparum   Plasmodium falciparum  0.000000e+00
# 1     Plasmodium falciparum            P falciparum  0.000000e+00
# 2     Plasmodium falciparum  Candida guilliermondii  1.490116e-08
# 3     Plasmodium falciparum                   yeast  0.000000e+00
# 4     Plasmodium falciparum       C. guilliermondii  0.000000e+00
# ...                     ...                     ...           ...
# 9995             M. arctica              Ni. lugens  0.000000e+00
# 9996             M. arctica     Acyrthosiphon pisum  1.490116e-08
# 9997             M. arctica     Megaphorura arctica  1.053671e-08
# 9998             M. arctica       Arctic springtail  0.000000e+00
# 9999             M. arctica              M. arctica  1.490116e-08
#
# [10000 rows x 3 columns]

# %%
#First scaled the distance by using min max scaler
from sklearn.preprocessing import MinMaxScaler

x = s['Distance'].values.reshape(-1,1)
min_max_scaler = MinMaxScaler()
scaled_conf = pd.Series(min_max_scaler.fit_transform(x).reshape(-1))
s.insert(3, "Scaled_Distance", scaled_conf, True)
s['Scaled_Distance'] = s['Scaled_Distance'].apply(lambda col: round(col,2))

# %%
proba = 1 - s['Scaled_Distance']
s.insert(4, "Probability", proba, True)

# %%
s
# Out:
#                          S1                      S2      Distance
# 0     Plasmodium falciparum   Plasmodium falciparum  0.000000e+00  \
# 1     Plasmodium falciparum            P falciparum  0.000000e+00
# 2     Plasmodium falciparum  Candida guilliermondii  1.490116e-08
# 3     Plasmodium falciparum                   yeast  0.000000e+00
# 4     Plasmodium falciparum       C. guilliermondii  0.000000e+00
# ...                     ...                     ...           ...
# 9995             M. arctica              Ni. lugens  0.000000e+00
# 9996             M. arctica     Acyrthosiphon pisum  1.490116e-08
# 9997             M. arctica     Megaphorura arctica  1.053671e-08
# 9998             M. arctica       Arctic springtail  0.000000e+00
# 9999             M. arctica              M. arctica  1.490116e-08
#
#       Scaled_Distance  Probability
# 0                0.00         1.00
# 1                0.00         1.00
# 2                0.71         0.29
# 3                0.00         1.00
# 4                0.00         1.00
# ...               ...          ...
# 9995             0.00         1.00
# 9996             0.71         0.29
# 9997             0.50         0.50
# 9998             0.00         1.00
# 9999             0.71         0.29
#
# [10000 rows x 5 columns]
